# %%
s=set()
s.add('python')
print(s)
# Out:
# {'python'}

# %%
s.add(50)
print(s)
# Out:
# {'python', 50}

# %%
f={"kiwi","apple"}
f.add("mango")
print(f)
# Out:
# {'kiwi', 'apple', 'mango'}

# %%
f.add("k.r.puram")
print(f)
# Out:
# {'k.r.puram', 'kiwi', 'apple', 'mango'}

# %%
f.add("TRUE")
print(f)
# Out:
# {'apple', 'k.r.puram', 'mango', 'kiwi', 'TRUE'}

# %%
f.update(["pink","blue","red"])
print(f)
# Out:
# {'blue', 'pink', 'apple', 'k.r.puram', 'mango', 'kiwi', 'TRUE', 'red'}

# %%
f.update([10,20,30])
print(f)
# Out:
# {'blue', 10, 'pink', 20, 'apple', 'k.r.puram', 'mango', 30, 'kiwi', 'TRUE', 'red'}

# %%
f.update(s)
print(f)
# Out:
# {'blue', 'python', 10, 'pink', 50, 20, 'apple', 'k.r.puram', 'mango', 30, 'kiwi', 'TRUE', 'red'}

# %%
t=(1,2,3,4,100,5,7,"banana")
s.update(t)
print(s)
# Out:
# {1, 2, 3, 4, 5, 100, 7, 'banana', 'python', 50}

# %%
f.remove("apple")
print(f)
# Out:
# {'blue', 'python', 10, 'pink', 50, 20, 'k.r.puram', 'mango', 30, 'kiwi', 'TRUE', 'red'}

# %%
s.remove(100)
print(s)
# Out:
# {1, 2, 3, 4, 5, 7, 'banana', 'python', 50}

# %%
f.remove("red")
print(f)
# Out:
# {'blue', 'python', 10, 'pink', 50, 20, 'k.r.puram', 'mango', 30, 'kiwi', 'TRUE'}

# %%
f.remove("k.r.puram")
print(f)
# Out:
# {'blue', 'python', 10, 'pink', 50, 20, 'mango', 30, 'kiwi', 'TRUE'}

# %%
s.discard("banana")
print(s)
# Out:
# {1, 2, 3, 4, 5, 7, 'python', 50}

# %%
s.discard(5)
print(s)
# Out:
# {1, 2, 3, 4, 7, 'python', 50}

# %%
s.discard("python")
print(s)
# Out:
# {1, 2, 3, 4, 7, 50}

# %%
f.discard("TRUE")
print(f)
# Out:
# {'blue', 'python', 10, 'pink', 50, 20, 'mango', 30, 'kiwi'}

# %%
f.pop()
print(f)
# Out:
# {10, 'pink', 50, 20, 'mango', 30, 'kiwi'}

# %%
c=s.pop()
print(c)
# Out:
# 1

# %%
f.clear()
print(f)
# Out:
# set()

# %%
s.clear()
print(s)
# Out:
# set()

# %%
c={1,2,3,4,5}
d={3,4,7,8,5}
t=c.union(d)
print(t)
# Out:
# {1, 2, 3, 4, 5, 7, 8}

# %%
v={"cucumber","carrot","bitter guard"}
f={"orange","apple","banana"}
b=v.union(f)
print(b)
# Out:
# {'apple', 'banana', 'cucumber', 'bitter guard', 'carrot', 'orange'}

# %%
e={2,4,6,8}
o={1,3,5,7}
l=e.union(o)
print(l)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
i={"bengaluor","ap"}
b={"kerala","tamilnadu"}
p=c.union(b)
print(p)
# Out:
# {'kerala', 'bengaluor', 'ap', 'tamilnadu'}

# %%
m={"maths","civics","pysics"}
b={"chemistry","maths","c"}
u=m.intersection(b)
print(u)
# Out:
# {'maths'}

# %%
c={1,2,3,4,5}
d={3,4,7,8,5}
g=c.intersection(d)
print(g)
# Out:
# {3, 4, 5}

# %%
vo={"a","e","i"}
ca={"v","i","d","a"}
h=vo.intersection(ca)
print(h)
# Out:
# {'a', 'i'}

# %%
atm=int(input("enter amount"))
if(atm<=10000):
  print("enable to withdraw" )
else:
  print("unable to withdraw")
# Out:
# enter amount8000
# enable to withdraw

# %%
shopping=int(input())
if(shopping>20000):
  print("you will get 10% discount")
else:
  print("not eligible for discount")
# Out:
# 25000
# you will get 10% discount

# %%
salary=int(input("enter salary:"))
cibil=int(input("enter cibil_score"))
if(salary>20000 and cibil>750):
  print("eligible for loan")
elif(salary>=20000 and cibil<=750):
  print("possible to get loan")
elif(salary>10000 and cibil<=650):
  print("difficult to get loan")
else:
  print("try to improve your salary and CIBIL_SCORE")
# Out:
# enter salary:20000
# enter cibil_score700
# possible to get loan

# %%
employee=int(input("enter experience:"))
salary=int(input("enter salary"))
if(employee>=1 and employee<4):
  print("bonus will be 2%",salary*(2/100))
elif(employee>=4):
  print("bonus will be 4%",salary*(4/100))
else:
  print("not eligle for bonus")
# Out:
# enter experience:4
# enter salary30000
# bonus will be 4% 1200.0

# %%
order=int(input("enter no.of items"))
amount=int(input("enter amount"))
if(amount>=1000):
  print("you will get free delivery")
else:
  print("not eligiblr for free delivery")
# Out:
# enter no.of items4
# enter amount500
# not eligiblr for free delivery

# %%
CGPA=int(input("enter your cgpa"))
backlogs=int(input("no.of backlogs"))
if(CGPA>=8 and backlogs==0):
  print("eligible for placements")
elif(CGPA>=6 and backlogs<=3):
  print("possible for placements")
else:
  print("not eligible for placements" )
# Out:
# enter your cgpa7
# no.of backlogs2
# possible for placements

# %%
emergency=int(input())
if(emergency>10):
  print("it is emergency and priority 1")
elif(emergency>=6):
  print("priority 2")
else:
  print("priority 3")
# Out:
# 9
# priority 2

# %%
dist=int(input("enter no.of kilometers:"))
price=30
if(dist>10):
  print("the price is maximum",dist*price)
elif(dist>=5):
  print("the price is affordable",dist*price)
else:
  print("the price is minimu")
# Out:
# enter no.of kilometers:9
# the price is affordable 270

# %%
a="abc@gmail.com"
b="123"
email=input("enter email ID:")
password=input("enter password:")
if(a==email and b==password):
  print("valid email")
else:
  print("invalid email")
# Out:
# enter email ID:abc@gmail.com
# enter password:123
# valid email

# %%
age=int(input())
if(age>15):
  print("eligible for movie ")
else:
  print("not eligiblr for movie")
# Out:
# 25
# eligible for movie

# %%
age=int(input("enter age"))
amount=4000
if(age>=65):
  print("they will get 4% discout",amount*(4/100))
elif(age>40):
  print("they will get 2 % discount",amount*(2/100))
else:
  print("not eligible for discount")
# Out:
# enter age60
# they will get 2 % discount 80.0

# %%
battery=int(input())
if(battery>80):
  print("fully charged")
elif(battery>=30):
  print("battery is medium you need to charge")
else:
  print("battery is low immediately need to cherge")
# Out:
# 60
# battery is medium you need to charge

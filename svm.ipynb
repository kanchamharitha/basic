# %%
import pandas as pd
df=pd.read_csv("heart.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df1=pd.read_csv("house_price_regression_dataset.csv")
df1.head()
# Out:
#    Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0            1360             2              1        1981  0.599637
# 1            4272             3              3        2016  4.753014
# 2            3592             1              2        2016  3.634823
# 3             966             1              2        1977  2.730667
# 4            4926             2              1        1993  4.699073
#
#    Garage_Size  Neighborhood_Quality   House_Price
# 0            0                     5  2.623829e+05
# 1            1                     6  9.852609e+05
# 2            0                     9  7.779774e+05
# 3            1                     8  2.296989e+05
# 4            0                     8  1.041741e+06

# %%
df1.columns
# Out:
# Index(['Square_Footage', 'Num_Bedrooms', 'Num_Bathrooms', 'Year_Built',
#        'Lot_Size', 'Garage_Size', 'Neighborhood_Quality', 'House_Price'],
#       dtype='object')

# %%
from sklearn.svm import SVC,SVR
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,accuracy_score

# %%
sc=SVC(kernel='linear')

# %%
x=df[['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
       'exang', 'oldpeak', 'slope', 'ca', 'thal']]
y=df['target']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
x_train
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 835   49    1   2       118   149    0        0      126      0      0.8
# 137   64    0   0       180   325    0        1      154      1      0.0
# 534   54    0   2       108   267    0        0      167      0      0.0
# 495   59    1   0       135   234    0        1      161      0      0.5
# 244   51    1   2       125   245    1        0      166      0      2.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 700   41    1   2       130   214    0        0      168      0      2.0
# 71    61    1   0       140   207    0        0      138      1      1.9
# 106   51    1   0       140   299    0        1      173      1      1.6
# 270   43    1   0       110   211    0        1      161      0      0.0
# 860   52    1   0       112   230    0        1      160      0      0.0
#
#      slope  ca  thal
# 835      2   3     2
# 137      2   0     2
# 534      2   0     2
# ...

# %%
sc.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
sc.fit(x_test,y_test)
# Out:
# SVC(kernel='linear')

# %%
y_pred_test=sc.predict(x_test)

# %%
accuracy=accuracy_score(y_pred_test,y_test)
print("accuracy:",accuracy)
# Out:
# accuracy: 0.8048780487804879

# %%
y_pred_train=sc.predict(x_train)

# %%
accuracy_train=accuracy_score(y_pred_train,y_train)
print("accuracy:",accuracy_train)
# Out:
# accuracy: 0.8621951219512195

# %%
sr=SVR(kernel='poly',degree=4)

# %%
x1=df1[['Square_Footage', 'Num_Bedrooms', 'Num_Bathrooms', 'Year_Built',
       'Lot_Size', 'Garage_Size', 'Neighborhood_Quality']]
y1=df1['House_Price']
x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=0.2,random_state=42)
x1_train
# Out:
#      Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 29             2028             2              3        1967  1.784790
# 535            3519             5              3        1966  4.009947
# 695            4507             2              3        2014  4.122337
# 557            3371             4              2        2000  1.580318
# 836            2871             5              1        1974  3.426914
# ..              ...           ...            ...         ...       ...
# 106            2257             5              1        1968  3.131006
# 270            3894             3              2        1975  1.256532
# 860            1484             5              1        2010  1.246555
# 435            1865             4              2        1994  4.354220
# 102            1363             4              1        1977  4.408878
#
#      Garage_Size  Neighborhood_Quality
# 29             2                     2
# ...

# %%
sr.fit(x1_train,y1_train)
# Out:
# SVR(degree=4, kernel='poly')

# %%
y1_pred_test=sr.predict(x1_test)
y1_pred_test
# Out:
# array([633208.80163431, 628750.76504369, 636861.80278947, 638444.39390651,
#        631726.02896674, 631477.68153709, 636518.28734485, 633687.59013803,
#        632210.41843292, 634276.77020327, 631579.92997209, 630056.01342826,
#        627858.40819846, 638351.56650338, 629110.58397422, 627874.44169732,
#        628604.12858801, 628197.32118381, 630734.41822676, 628025.47017505,
#        631130.06863181, 628721.48708703, 630682.59207647, 633702.09943093,
#        628379.94149273, 628063.44667061, 628400.26285311, 628338.19390895,
#        627880.38324143, 628407.3447308 , 627921.63596046, 634270.36355644,
#        631346.73324588, 628032.70489138, 628538.6380967 , 631562.9631311 ,
#        628520.60488056, 629125.57313652, 627897.31517372, 627838.54320897,
#        628002.76967241, 627903.54418655, 628630.22393705, 627984.83163926,
#        639031.71832447, 634944.91940925, 631909.81536563, 632226.92039395,
# ...

# %%
accracy_reg=r2_score(y1_pred_test,y1_test)
print("accuracy for regression:",accracy_reg)
# Out:
# accuracy for regression: -6833.697719060217

# %%
y1_pred_train=sr.predict(x1_train)

# %%
accuracy_reg_train=r2_score(y1_pred_train,y1_train)
print("accuracy for train:",accuracy_reg_train)
# Out:
# accuracy for train: -6779.352338366155

# %%
df1.columns
# Out:
# Index(['Square_Footage', 'Num_Bedrooms', 'Num_Bathrooms', 'Year_Built',
#        'Lot_Size', 'Garage_Size', 'Neighborhood_Quality', 'House_Price'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))

plt.subplot(2,2,1)
plt.scatter(df1["Square_Footage"],df1['House_Price'])

plt.subplot(2,2,2)
plt.scatter(df1['Num_Bedrooms'],df1['House_Price'])

plt.subplot(2,2,3)
plt.scatter(df1['Num_Bathrooms'],df1['House_Price'])

plt.subplot(2,2,4)
plt.scatter(df1['Year_Built'],df1['House_Price'])
plt.tight_layout()
plt.show()

# %%
plt.scatter(df1['Lot_Size'],df1['House_Price'])
plt.show()

# %%
plt.scatter(df1['Garage_Size'],df1['House_Price'])
plt.show()

# %%
plt.scatter(df1['Neighborhood_Quality'],df1['House_Price'])
plt.show()

# %%
df1.drop(['Year_Built','Lot_Size'],axis=1,inplace=True)

# %%
df1.head()
# Out:
#    Square_Footage  Num_Bedrooms  Num_Bathrooms  Garage_Size  \
# 0            1360             2              1            0
# 1            4272             3              3            1
# 2            3592             1              2            0
# 3             966             1              2            1
# 4            4926             2              1            0
#
#    Neighborhood_Quality   House_Price
# 0                     5  2.623829e+05
# 1                     6  9.852609e+05
# 2                     9  7.779774e+05
# 3                     8  2.296989e+05
# 4                     8  1.041741e+06

# %%
x1=df1[['Square_Footage', 'Num_Bathrooms']]
y1=df1['House_Price']
x1_train,x1_test,y1_train,y1_test=train_test_split(x_scale,y1,test_size=0.2,random_state=42)
x1_train
# Out:
# array([[-0.62748438,  1.25255918],
#        [ 0.5606704 ,  1.25255918],
#        [ 1.34799228,  1.25255918],
#        ...,
#        [-1.06098955, -1.18669921],
#        [-0.75737656,  0.03292999],
#        [-1.15741257, -1.18669921]])

# %%
sr.fit(x1_train,y1_train)
# Out:
# SVR(degree=4, kernel='poly')

# %%
y1_pred_test=sr.predict(x1_test)
y1_pred_test
# Out:
# array([629413.23406432, 629451.9753727 , 629407.89341484, 629312.19743395,
#        629431.07662307, 629450.32077671, 629413.44969006, 629443.91802176,
#        629425.46132794, 629396.89592638, 629450.2081523 , 629446.13316375,
#        629395.97320838, 629387.02887338, 629451.42878959, 629416.31761246,
#        629450.77572906, 629445.84711948, 629440.76470142, 629440.36048825,
#        629437.43359232, 629451.95871444, 629441.15327495, 629440.10497635,
#        629426.50617441, 629396.58110717, 629450.23791937, 629449.46219734,
#        629337.08124763, 629428.06444784, 629358.95863099, 629435.2649043 ,
#        629451.50429099, 629436.45872648, 629451.40537785, 629450.2179384 ,
#        629432.83853701, 629451.17201599, 629412.76387595, 629383.38545985,
#        629385.8198011 , 629424.011811  , 629450.84459746, 629431.18278776,
#        629395.54910302, 629437.08029635, 629449.60170188, 629449.08102353,
# ...

# %%
accracy_reg=r2_score(y1_pred_test,y1_test)
print("accuracy for regression:",accracy_reg)
# Out:
# accuracy for regression: -52075913.18915205

# %%
y1_pred_train=sr.predict(x1_train)

# %%
accuracy_reg_train=r2_score(y1_pred_train,y1_train)
print("accuracy for train:",accuracy_reg_train)
# Out:
# accuracy for train: -3477.040047356769

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()
x_scale=ss.fit_transform(x1)

# %%
from sklearn.preprocessing import MinMaxScaler
mx=MinMaxScaler()

# %%
df1.head()
# Out:
#    Square_Footage  Num_Bedrooms  Num_Bathrooms  Garage_Size  \
# 0            1360             2              1            0
# 1            4272             3              3            1
# 2            3592             1              2            0
# 3             966             1              2            1
# 4            4926             2              1            0
#
#    Neighborhood_Quality  House_Price
# 0                     5    262382.85
# 1                     6    985260.85
# 2                     9    777977.39
# 3                     8    229698.92
# 4                     8   1041740.86

# %%
df1["House_Price"]=df1["House_Price"].round(2)

# %%
x = df1[["Square_Footage"]]
y=df1["House_Price"]

# %%
y
# Out:
# 0       262382.85
# 1       985260.85
# 2       777977.39
# 3       229698.92
# 4      1041740.86
#           ...
# 995     701494.00
# 996     683723.16
# 997     572024.02
# 998     964865.30
# 999     742599.25
# Name: House_Price, Length: 1000, dtype: float64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
x_train
# Out:
#      Square_Footage
# 29             2028
# 535            3519
# 695            4507
# 557            3371
# 836            2871
# ..              ...
# 106            2257
# 270            3894
# 860            1484
# 435            1865
# 102            1363
#
# [800 rows x 1 columns]

# %%
model = SVR()
model.fit(x_train,y_train)
# Out:
# SVR()

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([629752.67786784, 629310.7551447 , 629708.83906345, 629674.38173091,
#        629712.83758092, 629701.60605016, 629718.36741914, 629755.11510716,
#        629733.3226477 , 629753.07811537, 629706.25219992, 629559.52070185,
#        629255.72839082, 629675.52268211, 629387.63579117, 629240.99243284,
#        629279.22531501, 629204.06695377, 629640.78899006, 629197.51296442,
#        629673.01932717, 629306.44233416, 629636.31237418, 629755.11226809,
#        629231.6985922 , 629196.01062668, 629238.07443182, 629226.27855227,
#        629236.77191072, 629237.56546957, 629217.76829898, 629752.29870608,
#        629690.2031674 , 629197.00926368, 629266.7111953 , 629705.87278887,
#        629260.70803342, 629392.87911287, 629229.62228177, 629273.69311921,
#        629199.21323871, 629226.29849476, 629286.19830218, 629202.05465488,
#        629664.00337018, 629746.65028371, 629723.69195182, 629732.94075691,
# ...

# %%
accuracy=r2_score(y_pred,y_test)

# %%
accuracy
# Out:
# -1351115.3728804006

# %%
l=[1,2,3,4,5,6,7,8]
print(l)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
l.append(9)
print(l)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
c=["hi","hello","world"]
l.extend(c)
print(l)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9, 'hi', 'hello', 'world']

# %%
l.insert(2,"go")

# %%
print(l)
# Out:
# [1, 2, 'go', 3, 4, 5, 6, 7, 8, 9, 'hi', 'hello', 'world']

# %%
l.pop()
print(l)
# Out:
# [1, 2, 'go', 3, 4, 5, 6, 7, 8, 9, 'hi', 'hello']

# %%
l.pop(5)
print(l)
# Out:
# [1, 2, 'go', 3, 4, 6, 7, 8, 9, 'hi', 'hello']

# %%
l.clear()
print(l)
# Out:
# []

# %%
a=[6,5,7,3,8,9,1]
print(a)
# Out:
# [6, 5, 7, 3, 8, 9, 1]

# %%
a.sort()
print(a)
# Out:
# [1, 3, 5, 6, 7, 8, 9]

# %%
a.reverse()
print(a)
# Out:
# [9, 8, 7, 6, 5, 3, 1]

# %%
print(a.count(9))
# Out:
# 1

# %%
print(a.index(8))
# Out:
# 1

# %%
b=a.copy()
print(b)
# Out:
# [9, 8, 7, 6, 5, 3, 1]

# %%
print(len(b))
# Out:
# 7

# %%
n=[9,8,7,0,4]
a.extend(n)
print(a)
# Out:
# [9, 8, 7, 6, 5, 3, 1, 9, 8, 7, 0, 4]

# %%
print(a.count(8))
# Out:
# 2

# %%
a.append(8)
print(a)
# Out:
# [8, 7, 6, 5, 3, 1, 9, 8, 7, 0, 4, 8, 8]

# %%
s=["a","o","t","b","u"]
print(s)
# Out:
# ['a', 'o', 't', 'b', 'u']

# %%
s.sort()
print(s)
# Out:
# ['a', 'b', 'o', 't', 'u']

# %%
s.reverse()
print(s)
# Out:
# ['u', 't', 'o', 'b', 'a']

# %%
a.remove(8)
print(a)
# Out:
# [7, 6, 5, 3, 1, 8, 7, 0, 4, 8, 8]

# %%
m=s.copy()
print(m)
# Out:
# ['u', 't', 'o', 'b', 'a']

# %%
m.append("a")
print(m)
# Out:
# ['u', 't', 'o', 'b', 'a', 'a']

# %%
m.count("a")
# Out:
# 2

# %%
j=len(m)//2
print(m.pop(j))
# Out:
# b

# %%
print(m)
# Out:
# ['u', 't', 'o', 'a', 'a']

# %%
m.append([1,2,3])
print(m)
# Out:
# ['u', 't', 'o', 'a', 'a', [1, 2, 3]]

# %%
r=[8,0,9]
m.extend(r)
print(m)
# Out:
# ['u', 't', 'o', 'a', 'a', [1, 2, 3], 8, 0, 9]

# %%
m.reverse()
print("1 st reverse",m)
m.reverse()
print("2nd reverse",m)
# Out:
# 1 st reverse [9, 0, 8, [1, 2, 3], 'a', 'a', 'o', 't', 'u']
# 2nd reverse ['u', 't', 'o', 'a', 'a', [1, 2, 3], 8, 0, 9]

# %%
print("before append",len(m))
m.append(6)
print("after append",len(m))
# Out:
# before append 9
# after append 10

# %%
num=[x for x in m if isinstance(x,int)]
st=[x for x in m if isinstance(x,str)]
num.sort()
st.sort()
print(num)
print(st)
# Out:
# [0, 6, 8, 9]
# ['a', 'a', 'o', 't', 'u']

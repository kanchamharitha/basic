# %%
stu={"name":["harsha","vijay","divya"],"age":[20,21,23]}
emp={"name":["harsha","vijay","divya"],"age":[39,28,27],"salary":[10000,8000,20000]}
print(stu.keys())
print(emp.keys())
# Out:
# dict_keys(['name', 'age'])
# dict_keys(['name', 'age', 'salary'])

# %%
a=stu.keys()
b=emp.keys()
print(a,b)
# Out:
# dict_keys(['name', 'age']) dict_keys(['name', 'age', 'salary'])

# %%
c=list(a)
print(c)
# Out:
# ['name', 'age']

# %%
v=stu.items()
print(v)
# Out:
# dict_items([('name', ['harsha', 'vijay', 'divya']), ('age', [20, 21, 23])])

# %%
print(stu.values())
# Out:
# dict_values([['harsha', 'vijay', 'divya'], [20, 21, 23]])

# %%
print(emp.get("salary"))
# Out:
# [10000, 8000, 20000]

# %%
d=stu.values()
print(d)
# Out:
# dict_values([['harsha', 'vijay', 'divya'], [20, 21, 23]])

# %%
li=list(d)
print(li)
# Out:
# [['harsha', 'vijay', 'divya'], [20, 21, 23]]

# %%
print(stu)
# Out:
# {'name': ['harsha', 'vijay', 'divya'], 'age': [20, 21, 23]}

# %%
print(emp)
# Out:
# {'name': ['harsha', 'vijay', 'divya'], 'age': [39, 28, 27], 'salary': [10000, 8000, 20000]}

# %%
print(stu.get("name"))
# Out:
# ['harsha', 'vijay', 'divya']

# %%
print(stu.get("age"))
# Out:
# [20, 21, 23]

# %%
print(stu.get("grade"))
# Out:
# None

# %%
print(stu.get("country"))
# Out:
# None

# %%
stu={"name":["harsha","vijay","divya"],"age":[20,21,23]}
stu.update({"marks":[25,60,98]})
print(stu)
# Out:
# {'name': ['harsha', 'vijay', 'divya'], 'age': [20, 21, 23], 'marks': [25, 60, 98]}

# %%
stu.update(emp)
print(stu)
# Out:
# {'name': ['harsha', 'vijay', 'divya'], 'age': [39, 28, 27], 'marks': [25, 60, 98], 'salary': [10000, 8000, 20000]}

# %%
emp.update({"city":["ap","kerala","mumbai"]})
print(emp)
# Out:
# {'name': ['harsha', 'vijay', 'divya'], 'age': [39, 28, 27], 'salary': [10000, 8000, 20000], 'city': ['ap', 'kerala', 'mumbai']}

# %%
emp.pop("salary")
print(stu)
print(emp)
# Out:
# {'name': ['harsha', 'vijay', 'divya'], 'marks': [25, 60, 98], 'salary': [10000, 8000, 20000]}
# {'name': ['harsha', 'vijay', 'divya'], 'age': [39, 28, 27], 'city': ['ap', 'kerala', 'mumbai']}

# %%
j=emp.pop("city")
print(j)
# Out:
# ['ap', 'kerala', 'mumbai']

# %%
stu.clear()

# %%
print(stu)
# Out:
# {}

# %%
emp.clear()
print(emp)
# Out:
# {}
